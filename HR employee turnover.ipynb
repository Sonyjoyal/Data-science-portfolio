# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv('HR_comma_sep (1).csv')
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df.ndim
# Out:
# 2

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df['left'].unique() #what are the types inside the column
# Out:
# array([1, 0], dtype=int64)

# %%
df['Department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
df1=df.drop(['Department','salary'],axis=1)

# %%
df1
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df1.groupby('left').mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
df1.drop(['promotion_last_5years'],axis=1) #keep the column which has some more difference drop the remaining column
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
x=df.drop(['last_evaluation','number_project','Work_accident','promotion_last_5years','Department'],axis=1)
x
# Out:
#        satisfaction_level  average_montly_hours  time_spend_company  left  \
# 0                    0.38                   157                   3     1
# 1                    0.80                   262                   6     1
# 2                    0.11                   272                   4     1
# 3                    0.72                   223                   5     1
# 4                    0.37                   159                   3     1
# ...                   ...                   ...                 ...   ...
# 14994                0.40                   151                   3     1
# 14995                0.37                   160                   3     1
# 14996                0.37                   143                   3     1
# 14997                0.11                   280                   4     1
# 14998                0.37                   158                   3     1
#
#        salary
# 0         low
# 1      medium
# 2      medium
# 3         low
# ...

# %%
import matplotlib.pyplot as plt

# %%
xpoints=x[['satisfaction_level','average_montly_hours','time_spend_company','salary']]
ypoints=x['left']

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar')  #crosstab-another visualization tool in pandas
# Out:
# <Axes: xlabel='salary'>

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
x
# Out:
#        satisfaction_level  average_montly_hours  time_spend_company  left  \
# 0                    0.38                   157                   3     1
# 1                    0.80                   262                   6     1
# 2                    0.11                   272                   4     1
# 3                    0.72                   223                   5     1
# 4                    0.37                   159                   3     1
# ...                   ...                   ...                 ...   ...
# 14994                0.40                   151                   3     1
# 14995                0.37                   160                   3     1
# 14996                0.37                   143                   3     1
# 14997                0.11                   280                   4     1
# 14998                0.37                   158                   3     1
#
#        salary
# 0         low
# 1      medium
# 2      medium
# 3         low
# ...

# %%
df2=x.drop(['left'],axis=1)

# %%
df2
# Out:
#        satisfaction_level  average_montly_hours  time_spend_company  salary
# 0                    0.38                   157                   3     low
# 1                    0.80                   262                   6  medium
# 2                    0.11                   272                   4  medium
# 3                    0.72                   223                   5     low
# 4                    0.37                   159                   3     low
# ...                   ...                   ...                 ...     ...
# 14994                0.40                   151                   3     low
# 14995                0.37                   160                   3     low
# 14996                0.37                   143                   3     low
# 14997                0.11                   280                   4     low
# 14998                0.37                   158                   3     low
#
# [14999 rows x 4 columns]

# %%
df2['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
salaries_dummy=pd.get_dummies(df2.salary,prefix='salary').astype(int)
salaries_dummy
# Out:
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# 1                0           0              1
# 2                0           0              1
# 3                0           1              0
# 4                0           1              0
# ...            ...         ...            ...
# 14994            0           1              0
# 14995            0           1              0
# 14996            0           1              0
# 14997            0           1              0
# 14998            0           1              0
#
# [14999 rows x 3 columns]

# %%
df2
# Out:
#        satisfaction_level  average_montly_hours  time_spend_company  salary
# 0                    0.38                   157                   3     low
# 1                    0.80                   262                   6  medium
# 2                    0.11                   272                   4  medium
# 3                    0.72                   223                   5     low
# 4                    0.37                   159                   3     low
# ...                   ...                   ...                 ...     ...
# 14994                0.40                   151                   3     low
# 14995                0.37                   160                   3     low
# 14996                0.37                   143                   3     low
# 14997                0.11                   280                   4     low
# 14998                0.37                   158                   3     low
#
# [14999 rows x 4 columns]

# %%
df3=pd.concat([df2,salaries_dummy],axis=1) #combine two dataframes
df3
# Out:
#        satisfaction_level  average_montly_hours  time_spend_company  salary  \
# 0                    0.38                   157                   3     low
# 1                    0.80                   262                   6  medium
# 2                    0.11                   272                   4  medium
# 3                    0.72                   223                   5     low
# 4                    0.37                   159                   3     low
# ...                   ...                   ...                 ...     ...
# 14994                0.40                   151                   3     low
# 14995                0.37                   160                   3     low
# 14996                0.37                   143                   3     low
# 14997                0.11                   280                   4     low
# 14998                0.37                   158                   3     low
#
#        salary_high  salary_low  salary_medium
# ...

# %%
x=df3.drop(['salary'],axis=1)

# %%
y=df['left']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.769

# %%
y_test
# Out:
# 1884     1
# 5572     0
# 6817     0
# 10044    0
# 4606     0
#         ..
# 9768     0
# 14270    1
# 7181     0
# 10202    0
# 1033     1
# Name: left, Length: 3000, dtype: int64

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[2100,  153],
#        [ 540,  207]], dtype=int64)

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(cm,annot=True,fmt='d') # fmt='d' - to convert the float into integer
plt.xlabel('Predicted') #in this case the independent variable should be in x
plt.ylabel('Actual')
# Out:
# Text(95.72222222222221, 0.5, 'Actual')
